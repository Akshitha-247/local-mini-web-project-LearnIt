# %%
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8" />
<meta name="viewport" content="width=device-width, initial-scale=1" />
<title>Homepage</title>
<style>
  body { font-family: Arial, sans-serif; margin: 0; background: #f4f4f4; }
  nav {
    background: #333;
    padding: 10px 20px;
    display: flex;
    gap: 15px;
  }
  nav button {
    background: none;
    border: none;
    color: white;
    font-weight: bold;
    font-size: 1em;
    cursor: pointer;
    padding: 10px 15px;
  }
  nav button:hover {
    background: #575757;
    border-radius: 4px;
  }
  header {
    background: #007BFF;
    color: white;
    padding: 60px 20px;
    text-align: center;
  }
  .banner h1 {
    margin: 0;
    font-size: 3em;
  }
  .banner p {
    font-size: 1.3em;
    margin: 10px 0 20px;
  }
  .search-bar {
    max-width: 400px;
    margin: 20px auto;
    display: flex;
  }
  .search-bar input[type="text"] {
    flex-grow: 1;
    padding: 10px;
    font-size: 1em;
    border: 2px solid #007BFF;
    border-right: none;
    border-radius: 5px 0 0 5px;
  }
  .search-bar button {
    padding: 10px 20px;
    border: 2px solid #007BFF;
    background: #007BFF;
    color: white;
    font-weight: bold;
    border-radius: 0 5px 5px 0;
    cursor: pointer;
  }
  .search-bar button:hover {
    background: #0056b3;
  }
  .featured-slider {
    max-width: 800px;
    margin: 40px auto;
    background: white;
    padding: 20px;
    border-radius: 8px;
  }
  .featured-slider h2 {
    margin-top: 0;
    margin-bottom: 20px;
  }
  .tutorial-slide {
    border: 1px solid #ddd;
    padding: 15px;
    margin-bottom: 15px;
    border-radius: 5px;
    cursor: pointer;
  }
  .tutorial-slide:hover {
    background: #f0f8ff;
  }
  .tutorial-slide h3 {
    margin: 0 0 5px;
  }
  .cta-buttons {
    text-align: center;
    margin: 40px 0;
  }
  .cta-buttons button {
    background: #28a745;
    color: white;
    border: none;
    padding: 15px 30px;
    font-size: 1.2em;
    margin: 0 10px;
    border-radius: 6px;
    cursor: pointer;
  }
  .cta-buttons button:hover {
    background: #1e7e34;
  }
</style>
</head>
<body>

<nav>
  <button onclick="openPage('home')">Home</button>
  <button onclick="openPage('tutorials')">Tutorials</button>
  <button onclick="openPage('projects')">Projects</button>
  <button onclick="openPage('about')">About Us</button>
  <button onclick="openPage('contact')">Contact</button>
</nav>

<header class="banner">
  <h1>Welcome to LearnIt!</h1>
  <p>Your one-stop platform for tutorials and projects in coding and development.</p>

  <div class="search-bar">
    <input type="text" placeholder="Search tutorials or projects..." id="searchInput" />
    <button onclick="search()">Search</button>
  </div>
</header>

<section class="featured-slider">
  <h2>Featured Tutorials</h2>
  <div class="tutorial-slide" onclick="openTutorial('Python Basics for Beginners')">
    <h3>Python Basics for Beginners</h3>
    <p>Learn the fundamentals of Python programming with easy-to-follow lessons.</p>
  </div>
  <div class="tutorial-slide" onclick="openTutorial('Building Web Apps with Flask')">
    <h3>Building Web Apps with Flask</h3>
    <p>Create dynamic web applications using the Flask framework in Python.</p>
  </div>
  <div class="tutorial-slide" onclick="openTutorial('Data Visualization with Matplotlib')">
    <h3>Data Visualization with Matplotlib</h3>
    <p>Master the art of visualizing data with Matplotlib library.</p>
  </div>
</section>

<div class="cta-buttons">
  <button onclick="openPage('tutorials')">Start Learning</button>
  <button onclick="openPage('projects')">Browse Projects</button>
</div>

<script>
  function openPage(page) {
    const contentMap = {
      home: "<h1>Home</h1><p>Welcome to the home page. Explore tutorials and projects.</p>",
      tutorials: "<h1>Tutorials</h1><p>Here are some tutorials to get you started.</p><ul><li>Python Basics</li><li>Flask Web Apps</li><li>Data Visualization</li></ul>",
      projects: "<h1>Projects</h1><p>Browse exciting coding projects here.</p><ul><li>Weather App</li><li>Todo List</li><li>Blog Platform</li></ul>",
      about: "<h1>About Us</h1><p>LearnIt is dedicated to providing quality coding tutorials and projects.</p>",
      contact: `<h1>Contact Us</h1>
                <p>Email: support@learnit.com</p>
                <p>Phone: +123 456 7890</p>
                <form onsubmit="alert('Thanks for reaching out! We will get back to you soon.'); return false;">
                  <label>Name:<br><input type='text' required></label><br><br>
                  <label>Email:<br><input type='email' required></label><br><br>
                  <label>Message:<br><textarea required></textarea></label><br><br>
                  <button type='submit'>Send</button>
                </form>`
    };
    const newWin = window.open();
    newWin.document.write("<html><head><title>" + page.charAt(0).toUpperCase() + page.slice(1) + "</title></head><body style='font-family: Arial, sans-serif; padding:20px;'>" + contentMap[page] + "</body></html>");
    newWin.document.close();
  }

  function search() {
    let query = document.getElementById('searchInput').value.trim().toLowerCase();
    if(!query) {
      alert('Please enter a search term.');
      return;
    }
    const tutorials = ['python basics for beginners', 'building web apps with flask', 'data visualization with matplotlib'];
    const projects = ['weather app', 'todo list', 'blog platform'];

    let results = [];

    tutorials.forEach(t => { if(t.includes(query)) results.push("Tutorial: " + t); });
    projects.forEach(p => { if(p.includes(query)) results.push("Project: " + p); });

    const newWin = window.open();
    newWin.document.write("<html><head><title>Search Results</title></head><body style='font-family: Arial, sans-serif; padding:20px;'>");
    newWin.document.write("<h1>Search Results for '" + query + "'</h1>");
    if(results.length > 0) {
      newWin.document.write("<ul>");
      results.forEach(r => newWin.document.write("<li>" + r + "</li>"));
      newWin.document.write("</ul>");
    } else {
      newWin.document.write("<p>No results found.</p>");
    }
    newWin.document.write("</body></html>");
    newWin.document.close();
  }

  function openTutorial(name) {
    const newWin = window.open();
    newWin.document.write("<html><head><title>" + name + "</title></head><body style='font-family: Arial, sans-serif; padding:20px;'>");
    newWin.document.write("<h1>" + name + "</h1>");
    newWin.document.write("<p>This is a detailed tutorial page for <strong>" + name + "</strong>. Content coming soon!</p>");
    newWin.document.write("</body></html>");
    newWin.document.close();
  }
</script>

</body>
</html>
"""

import http.server
import socketserver
import threading
import webbrowser
import tempfile
import os

temp_dir = tempfile.TemporaryDirectory()
html_path = os.path.join(temp_dir.name, "index.html")
with open(html_path, "w") as f:
    f.write(html_content)

PORT = 8000
Handler = http.server.SimpleHTTPRequestHandler
os.chdir(temp_dir.name)

def serve():
    with socketserver.TCPServer(("", PORT), Handler) as httpd:
        print(f"Serving at http://localhost:{PORT}/index.html")
        httpd.serve_forever()

server_thread = threading.Thread(target=serve, daemon=True)
server_thread.start()

webbrowser.open_new_tab(f"http://localhost:{PORT}/index.html")
# Out:
# Exception ignored in: <finalize object at 0x1b648681a60; dead>
# Traceback (most recent call last):
#   File "C:\Users\vihan\AppData\Local\Programs\Python\Python312\Lib\weakref.py", line 590, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vihan\AppData\Local\Programs\Python\Python312\Lib\tempfile.py", line 935, in _cleanup
#     cls._rmtree(name, ignore_errors=ignore_errors)
#   File "C:\Users\vihan\AppData\Local\Programs\Python\Python312\Lib\tempfile.py", line 930, in _rmtree
#     _shutil.rmtree(name, onexc=onexc)
#   File "C:\Users\vihan\AppData\Local\Programs\Python\Python312\Lib\shutil.py", line 820, in rmtree
#     return _rmtree_unsafe(path, onexc)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\vihan\AppData\Local\Programs\Python\Python312\Lib\shutil.py", line 652, in _rmtree_unsafe
#     onexc(os.rmdir, path, err)
# ...
